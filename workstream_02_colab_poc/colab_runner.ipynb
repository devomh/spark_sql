# %% [markdown]
# # Spark SQL Plan POC Runner
#
# Run these cells in Google Colab after uploading or cloning this repository. The workload creates synthetic warehouse tables, runs Spark SQL queries, and saves plan artifacts for later analysis.

# %%
# !apt-get update -qq
# !apt-get install -y openjdk-17-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.5.1/spark-3.5.1-bin-hadoop3.tgz
# !tar -xzf spark-3.5.1-bin-hadoop3.tgz -C /content
# !pip install -q findspark

# %%
import os

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.5.1-bin-hadoop3"

# %%
# Change this path if you uploaded the folder somewhere else.
POC_DIR = "/content/spark_sql/workstream_02_colab_poc"
BASE_DIR = "/content/spark_sql_plan_poc"

# %%
# !python "$POC_DIR/colab_poc.py" \
  --start-standalone \
  --base-dir "$BASE_DIR" \
  --fact-rows 300000

# %%
# !find "$BASE_DIR/artifacts/runs" -maxdepth 3 -type f | sort | head -80
